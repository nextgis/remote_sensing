# %% [markdown]
# # Базовые слои

# %% [markdown]
# В документе рассматривается вопрос об устойчивости базовых карт. Сами карты были созданы с использованием медианы зимних снимков и [импортированы в проект](000_Initialization.ipynb#import_landsat_composites).

# %% [markdown]
# ## Устойчивость базовых слоев

# %% [markdown]
# Прежде, чем начинать работать с базовыми слоями, нужно понять, насколько они отличаются друг от друга. В идеале, нужно, чтобы слои, полученные в разные годы, были одинаковыми, а различались в них лишь те участки, которые подверглись реальному изменению. В данном подразделе рассматривается вопрос о том какова величина этих различий.

# %%
import os

import utilites
reload(utilites)

from utilites import (
    get_gisbase_path,
    get_grassdata_path,
    get_location_name,
    get_ll_location_name,
    get_location_path,
)

print get_location_path()

from grasslib import GRASS

# %%
grs = GRASS(gisbase=get_gisbase_path(), 
            dbase=get_grassdata_path(), 
            location=get_location_name(),
            mapset='basemaps'
)
# print grs.grass.read_command('g.mapset', mapset='basemaps')
print grs.grass.read_command('g.mapset', flags='p')

# %%
# %tb
# Установим охват, чтобы он накрывал все сцены
grs.grass.run_command('g.region', region='all_scenes@landsat')

grs.grass.run_command('g.remove', type='rast', pattern='diff*', flags='f')

for band_num in range(1, 12):
    print band_num
    
    for (new_year_pref, old_year_pref, diff_pref) in [
        ('composite16.', 'composite15.', 'diff1615.'),
        ('composite17.', 'composite16.', 'diff1716.')
    ]:
    
        new_year = new_year_pref + str(band_num) + '@basemaps'
        old_year = old_year_pref + str(band_num) + '@basemaps'
        diff = diff_pref + str(band_num)
        command = "%(out)s = %(new_year)s - %(old_year)s" % dict(out=diff, new_year=new_year, old_year=old_year)
        print command
        grs.grass.mapcalc("${out} = ${new_year} - ${old_year}", 
                          out=diff, new_year=new_year, old_year=old_year
                         )        
        norm_diff = 'norm.' +  diff
        grs.grass.mapcalc("${out} = (${new_year} - ${old_year}) / (${new_year} + ${old_year})", 
                          out=norm_diff, new_year=new_year, old_year=old_year)

# %%
for band_num in range(1, 12):
    print "----- BAND %s ------- " % (band_num, )
    print grs.grass.read_command('r.report', map='diff1615.'+str(band_num), 
                                 units='c', nsteps=10, sort='desc', flags='h')
    print grs.grass.read_command('r.report', map='diff1716.'+str(band_num), 
                                 units='c', nsteps=10, sort='desc', flags='h')

# %% [raw]
# ----- BAND 1 -------
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.037097-0.134831|from  to . . . . . . . . . . . . . . . . . . . | 65699459|
# |-0.209024--0.037097|from  to . . . . . . . . . . . . . . . . . . . | 43427827|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 30275638|
# |-0.380952--0.209024|from  to . . . . . . . . . . . . . . . . . . . | 10971212|
# | -0.55288--0.380952|from  to . . . . . . . . . . . . . . . . . . . |  6633430|
# | -0.724807--0.55288|from  to . . . . . . . . . . . . . . . . . . . |    68263|
# |-0.896735--0.724807|from  to . . . . . . . . . . . . . . . . . . . |    13425|
# |  0.134831-0.306759|from  to . . . . . . . . . . . . . . . . . . . |    12800|
# |-1.068663--0.896735|from  to . . . . . . . . . . . . . . . . . . . |     2311|
# |  0.306759-0.478687|from  to . . . . . . . . . . . . . . . . . . . |      598|
# | -1.24059--1.068663|from  to . . . . . . . . . . . . . . . . . . . |      138|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.087557-0.074519|from  to . . . . . . . . . . . . . . . . . . . | 82306924|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 38380628|
# |  0.074519-0.236596|from  to . . . . . . . . . . . . . . . . . . . | 23608101|
# |  0.236596-0.398672|from  to . . . . . . . . . . . . . . . . . . . |  6435856|
# |  0.398672-0.560748|from  to . . . . . . . . . . . . . . . . . . . |  3515273|
# |-0.249634--0.087557|from  to . . . . . . . . . . . . . . . . . . . |  2510974|
# | -0.41171--0.249634|from  to . . . . . . . . . . . . . . . . . . . |   338653|
# |  0.560748-0.722825|from  to . . . . . . . . . . . . . . . . . . . |     4657|
# | -0.573786--0.41171|from  to . . . . . . . . . . . . . . . . . . . |     3521|
# |  0.722825-0.884901|from  to . . . . . . . . . . . . . . . . . . . |      460|
# |  0.884901-1.046978|from  to . . . . . . . . . . . . . . . . . . . |       54|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# ----- BAND 2 -------
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.039703-0.158404|from  to . . . . . . . . . . . . . . . . . . . | 67869463|
# |-0.237809--0.039703|from  to . . . . . . . . . . . . . . . . . . . | 42701599|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 30275638|
# |-0.435915--0.237809|from  to . . . . . . . . . . . . . . . . . . . | 11118505|
# |-0.634022--0.435915|from  to . . . . . . . . . . . . . . . . . . . |  5055444|
# |-0.832128--0.634022|from  to . . . . . . . . . . . . . . . . . . . |    56307|
# |-1.030235--0.832128|from  to . . . . . . . . . . . . . . . . . . . |    13057|
# |   0.158404-0.35651|from  to . . . . . . . . . . . . . . . . . . . |    11993|
# |-1.228341--1.030235|from  to . . . . . . . . . . . . . . . . . . . |     2372|
# |   0.35651-0.554617|from  to . . . . . . . . . . . . . . . . . . . |      577|
# |-1.426447--1.228341|from  to . . . . . . . . . . . . . . . . . . . |      146|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.086948-0.102234|from  to . . . . . . . . . . . . . . . . . . . | 89389817|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 38380628|
# |  0.102234-0.291416|from  to . . . . . . . . . . . . . . . . . . . | 18419760|
# |  0.291416-0.480599|from  to . . . . . . . . . . . . . . . . . . . |  6984091|
# |-0.276131--0.086948|from  to . . . . . . . . . . . . . . . . . . . |  2783742|
# |  0.480599-0.669781|from  to . . . . . . . . . . . . . . . . . . . |   828229|
# |-0.465313--0.276131|from  to . . . . . . . . . . . . . . . . . . . |   313558|
# |  0.669781-0.858964|from  to . . . . . . . . . . . . . . . . . . . |     3374|
# |-0.654496--0.465313|from  to . . . . . . . . . . . . . . . . . . . |     1505|
# |  0.858964-1.048146|from  to . . . . . . . . . . . . . . . . . . . |      349|
# |  1.048146-1.237328|from  to . . . . . . . . . . . . . . . . . . . |       48|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# ----- BAND 3 -------
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.049017-0.162578|from  to . . . . . . . . . . . . . . . . . . . | 77011939|
# |-0.260612--0.049017|from  to . . . . . . . . . . . . . . . . . . . | 36947601|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 30275638|
# |-0.472208--0.260612|from  to . . . . . . . . . . . . . . . . . . . | 11778378|
# |-0.683803--0.472208|from  to . . . . . . . . . . . . . . . . . . . |  1013276|
# |-0.895398--0.683803|from  to . . . . . . . . . . . . . . . . . . . |    46825|
# |  0.162578-0.374173|from  to . . . . . . . . . . . . . . . . . . . |    16797|
# |-1.106993--0.895398|from  to . . . . . . . . . . . . . . . . . . . |    11586|
# |-1.318588--1.106993|from  to . . . . . . . . . . . . . . . . . . . |     2155|
# |  0.374173-0.585768|from  to . . . . . . . . . . . . . . . . . . . |      776|
# |-1.530183--1.318588|from  to . . . . . . . . . . . . . . . . . . . |      130|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.066573-0.131826|from  to . . . . . . . . . . . . . . . . . . . | 96832890|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 38380628|
# |  0.131826-0.330225|from  to . . . . . . . . . . . . . . . . . . . | 12535088|
# |  0.330225-0.528625|from  to . . . . . . . . . . . . . . . . . . . |  5534664|
# |-0.264973--0.066573|from  to . . . . . . . . . . . . . . . . . . . |  3487842|
# |-0.463372--0.264973|from  to . . . . . . . . . . . . . . . . . . . |   310116|
# |  0.528625-0.727024|from  to . . . . . . . . . . . . . . . . . . . |    20551|
# |  0.727024-0.925424|from  to . . . . . . . . . . . . . . . . . . . |     2651|
# |-0.661771--0.463372|from  to . . . . . . . . . . . . . . . . . . . |      314|
# |  0.925424-1.123823|from  to . . . . . . . . . . . . . . . . . . . |      311|
# |  1.123823-1.322222|from  to . . . . . . . . . . . . . . . . . . . |       46|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# ----- BAND 4 -------
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.074239-0.172278|from  to . . . . . . . . . . . . . . . . . . . | 82570960|
# |-0.320755--0.074239|from  to . . . . . . . . . . . . . . . . . . . | 32478946|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 30275638|
# |-0.567272--0.320755|from  to . . . . . . . . . . . . . . . . . . . | 11291453|
# |-0.813789--0.567272|from  to . . . . . . . . . . . . . . . . . . . |   402699|
# |-1.060305--0.813789|from  to . . . . . . . . . . . . . . . . . . . |    47158|
# |  0.172278-0.418794|from  to . . . . . . . . . . . . . . . . . . . |    22479|
# |-1.306822--1.060305|from  to . . . . . . . . . . . . . . . . . . . |    12224|
# |-1.553338--1.306822|from  to . . . . . . . . . . . . . . . . . . . |     2457|
# |  0.418794-0.665311|from  to . . . . . . . . . . . . . . . . . . . |      918|
# |-1.799855--1.553338|from  to . . . . . . . . . . . . . . . . . . . |      169|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.065387-0.172619|from  to . . . . . . . . . . . . . . . . . . . | 98324086|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 38380628|
# |  0.172619-0.410624|from  to . . . . . . . . . . . . . . . . . . . | 11620923|
# |   0.410624-0.64863|from  to . . . . . . . . . . . . . . . . . . . |  4731418|
# |-0.303392--0.065387|from  to . . . . . . . . . . . . . . . . . . . |  3775466|
# |-0.541398--0.303392|from  to . . . . . . . . . . . . . . . . . . . |   251458|
# |   0.64863-0.886636|from  to . . . . . . . . . . . . . . . . . . . |    17814|
# |  0.886636-1.124641|from  to . . . . . . . . . . . . . . . . . . . |     2735|
# |  1.124641-1.362647|from  to . . . . . . . . . . . . . . . . . . . |      330|
# |-0.779404--0.541398|from  to . . . . . . . . . . . . . . . . . . . |      205|
# |  1.362647-1.600652|from  to . . . . . . . . . . . . . . . . . . . |       38|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# ----- BAND 5 -------
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.054521-0.202628|from  to . . . . . . . . . . . . . . . . . . . | 92935583|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 30275638|
# | -0.31167--0.054521|from  to . . . . . . . . . . . . . . . . . . . | 28314736|
# | -0.568819--0.31167|from  to . . . . . . . . . . . . . . . . . . . |  5247821|
# |-0.825969--0.568819|from  to . . . . . . . . . . . . . . . . . . . |   244999|
# |  0.202628-0.459778|from  to . . . . . . . . . . . . . . . . . . . |    40694|
# |-1.083118--0.825969|from  to . . . . . . . . . . . . . . . . . . . |    34057|
# |-1.340267--1.083118|from  to . . . . . . . . . . . . . . . . . . . |     9386|
# |-1.597417--1.340267|from  to . . . . . . . . . . . . . . . . . . . |     1618|
# |  0.459778-0.716927|from  to . . . . . . . . . . . . . . . . . . . |      496|
# |-1.854566--1.597417|from  to . . . . . . . . . . . . . . . . . . . |       73|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.052109-0.211752|from  to . . . . . . . . . . . . . . . . . . . | 91099927|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 38380628|
# |-0.315971--0.052109|from  to . . . . . . . . . . . . . . . . . . . | 18995620|
# |  0.211752-0.475614|from  to . . . . . . . . . . . . . . . . . . . |  8108574|
# |  0.475614-0.739476|from  to . . . . . . . . . . . . . . . . . . . |   394702|
# |-0.579833--0.315971|from  to . . . . . . . . . . . . . . . . . . . |   113690|
# |  0.739476-1.003337|from  to . . . . . . . . . . . . . . . . . . . |     9824|
# |  1.003337-1.267199|from  to . . . . . . . . . . . . . . . . . . . |     1480|
# |-0.843694--0.579833|from  to . . . . . . . . . . . . . . . . . . . |      475|
# |   1.267199-1.53106|from  to . . . . . . . . . . . . . . . . . . . |      158|
# |   1.53106-1.794922|from  to . . . . . . . . . . . . . . . . . . . |       23|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# ----- BAND 6 -------
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.037937-0.089155|from  to . . . . . . . . . . . . . . . . . . . |124173404|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 30275638|
# |  0.089155-0.216246|from  to . . . . . . . . . . . . . . . . . . . |  2217216|
# |-0.165028--0.037937|from  to . . . . . . . . . . . . . . . . . . . |   428294|
# | -0.29212--0.165028|from  to . . . . . . . . . . . . . . . . . . . |     6086|
# |  0.216246-0.343338|from  to . . . . . . . . . . . . . . . . . . . |     3985|
# | -0.419211--0.29212|from  to . . . . . . . . . . . . . . . . . . . |      261|
# |  0.343338-0.470429|from  to . . . . . . . . . . . . . . . . . . . |      176|
# |-0.546302--0.419211|from  to . . . . . . . . . . . . . . . . . . . |       21|
# |-0.673394--0.546302|from  to . . . . . . . . . . . . . . . . . . . |       12|
# |-0.800485--0.673394|from  to . . . . . . . . . . . . . . . . . . . |        8|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# |-0.152291--0.006996|from  to . . . . . . . . . . . . . . . . . . . | 72762332|
# | -0.006996-0.138299|from  to . . . . . . . . . . . . . . . . . . . | 45582789|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 38380628|
# |  0.138299-0.283593|from  to . . . . . . . . . . . . . . . . . . . |   292033|
# |-0.297585--0.152291|from  to . . . . . . . . . . . . . . . . . . . |    41000|
# |  0.283593-0.428888|from  to . . . . . . . . . . . . . . . . . . . |    37801|
# |  0.428888-0.574183|from  to . . . . . . . . . . . . . . . . . . . |     6708|
# |  0.574183-0.719477|from  to . . . . . . . . . . . . . . . . . . . |      874|
# | -0.44288--0.297585|from  to . . . . . . . . . . . . . . . . . . . |      835|
# |  0.719477-0.864772|from  to . . . . . . . . . . . . . . . . . . . |       89|
# |  0.864772-1.010067|from  to . . . . . . . . . . . . . . . . . . . |       12|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# ----- BAND 7 -------
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.025058-0.083632|from  to . . . . . . . . . . . . . . . . . . . |123599613|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 30275638|
# |-0.133749--0.025058|from  to . . . . . . . . . . . . . . . . . . . |  3173709|
# |  0.083632-0.192322|from  to . . . . . . . . . . . . . . . . . . . |    39208|
# |-0.242439--0.133749|from  to . . . . . . . . . . . . . . . . . . . |    14464|
# |  0.192322-0.301013|from  to . . . . . . . . . . . . . . . . . . . |     2077|
# | -0.35113--0.242439|from  to . . . . . . . . . . . . . . . . . . . |      226|
# |  0.301013-0.409703|from  to . . . . . . . . . . . . . . . . . . . |      111|
# |  -0.45982--0.35113|from  to . . . . . . . . . . . . . . . . . . . |       27|
# |-0.677201--0.568511|from  to . . . . . . . . . . . . . . . . . . . |       14|
# | -0.568511--0.45982|from  to . . . . . . . . . . . . . . . . . . . |       14|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.119005-0.016496|from  to . . . . . . . . . . . . . . . . . . . | 97223171|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 38380628|
# |  0.016496-0.151997|from  to . . . . . . . . . . . . . . . . . . . | 21260013|
# |  0.151997-0.287498|from  to . . . . . . . . . . . . . . . . . . . |   195872|
# |  0.287498-0.422999|from  to . . . . . . . . . . . . . . . . . . . |    28952|
# |-0.254506--0.119005|from  to . . . . . . . . . . . . . . . . . . . |    10452|
# |  0.422999-0.558499|from  to . . . . . . . . . . . . . . . . . . . |     4724|
# |     0.558499-0.694|from  to . . . . . . . . . . . . . . . . . . . |      616|
# |-0.390007--0.254506|from  to . . . . . . . . . . . . . . . . . . . |      594|
# |     0.694-0.829501|from  to . . . . . . . . . . . . . . . . . . . |       65|
# |  0.829501-0.965002|from  to . . . . . . . . . . . . . . . . . . . |       14|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# ----- BAND 8 -------
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# |-0.243914--0.015887|from  to . . . . . . . . . . . . . . . . . . . | 67637580|
# | -0.015887-0.212141|from  to . . . . . . . . . . . . . . . . . . . | 43876444|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 30275691|
# |-0.471942--0.243914|from  to . . . . . . . . . . . . . . . . . . . | 12688839|
# | -0.69997--0.471942|from  to . . . . . . . . . . . . . . . . . . . |  2535094|
# | -0.927998--0.69997|from  to . . . . . . . . . . . . . . . . . . . |    61123|
# |-1.156026--0.927998|from  to . . . . . . . . . . . . . . . . . . . |    15980|
# |  0.212141-0.440169|from  to . . . . . . . . . . . . . . . . . . . |    10103|
# |-1.384054--1.156026|from  to . . . . . . . . . . . . . . . . . . . |     3500|
# |  0.440169-0.668197|from  to . . . . . . . . . . . . . . . . . . . |      460|
# |-1.612082--1.384054|from  to . . . . . . . . . . . . . . . . . . . |      287|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.109765-0.112905|from  to . . . . . . . . . . . . . . . . . . . | 94311821|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 38380788|
# |  0.112905-0.335575|from  to . . . . . . . . . . . . . . . . . . . | 16067810|
# |  0.335575-0.558245|from  to . . . . . . . . . . . . . . . . . . . |  6053468|
# |-0.332435--0.109765|from  to . . . . . . . . . . . . . . . . . . . |  2138329|
# |-0.555105--0.332435|from  to . . . . . . . . . . . . . . . . . . . |   120820|
# |  0.558245-0.780916|from  to . . . . . . . . . . . . . . . . . . . |    28029|
# |  0.780916-1.003586|from  to . . . . . . . . . . . . . . . . . . . |     3479|
# |  1.003586-1.226256|from  to . . . . . . . . . . . . . . . . . . . |      470|
# |  1.226256-1.448926|from  to . . . . . . . . . . . . . . . . . . . |       59|
# |-0.777775--0.555105|from  to . . . . . . . . . . . . . . . . . . . |       28|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# ----- BAND 9 -------
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                  #|description                                    |    count|
# |-----------------------------------------------------------------------------|
# | -0.002575-0.000007|from  to . . . . . . . . . . . . . . . . . . . | 93987828|
# |                  *|no data. . . . . . . . . . . . . . . . . . . . | 30275638|
# |  0.000007-0.002588|from  to . . . . . . . . . . . . . . . . . . . | 22355899|
# |-0.005157--0.002575|from  to . . . . . . . . . . . . . . . . . . . |  9217559|
# |-0.007738--0.005157|from  to . . . . . . . . . . . . . . . . . . . |  1037994|
# | -0.01032--0.007738|from  to . . . . . . . . . . . . . . . . . . . |   157668|
# |   0.002588-0.00517|from  to . . . . . . . . . . . . . . . . . . . |    55228|
# | -0.012902--0.01032|from  to . . . . . . . . . . . . . . . . . . . |    15394|
# |-0.015484--0.012902|from  to . . . . . . . . . . . . . . . . . . . |     1535|
# |   0.00517-0.007752|from  to . . . . . . . . . . . . . . . . . . . |      278|
# |-0.018065--0.015484|from  to . . . . . . . . . . . . . . . . . . . |       80|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                 #|description                                     |    count|
# |-----------------------------------------------------------------------------|
# |  0.000585-0.00308|from  to . . . . . . . . . . . . . . . . . . . .| 75366832|
# |                 *|no data. . . . . . . . . . . . . . . . . . . . .| 38380628|
# | -0.00191-0.000585|from  to . . . . . . . . . . . . . . . . . . . .| 22649169|
# |  0.00308-0.005575|from  to . . . . . . . . . . . . . . . . . . . .| 18488157|
# |  0.005575-0.00807|from  to . . . . . . . . . . . . . . . . . . . .|  1731563|
# |  0.00807-0.010564|from  to . . . . . . . . . . . . . . . . . . . .|   328437|
# |-0.004405--0.00191|from  to . . . . . . . . . . . . . . . . . . . .|   107538|
# | 0.010564-0.013059|from  to . . . . . . . . . . . . . . . . . . . .|    48274|
# | 0.013059-0.015554|from  to . . . . . . . . . . . . . . . . . . . .|     3405|
# | -0.0069--0.004405|from  to . . . . . . . . . . . . . . . . . . . .|     1028|
# | 0.015554-0.018049|from  to . . . . . . . . . . . . . . . . . . . .|       70|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# ----- BAND 10 -------
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                 #|description                                     |    count|
# |-----------------------------------------------------------------------------|
# |  -1.23569-5.58044|from  to . . . . . . . . . . . . . . . . . . . .| 39282305|
# |  5.58044-12.39657|from  to . . . . . . . . . . . . . . . . . . . .| 35559450|
# |  12.39657-19.2127|from  to . . . . . . . . . . . . . . . . . . . .| 35118181|
# |                 *|no data. . . . . . . . . . . . . . . . . . . . .| 30275638|
# |  19.2127-26.02883|from  to . . . . . . . . . . . . . . . . . . . .| 11146209|
# | 26.02883-32.84496|from  to . . . . . . . . . . . . . . . . . . . .|  3503393|
# | -8.05182--1.23569|from  to . . . . . . . . . . . . . . . . . . . .|  1629404|
# | 32.84496-39.66109|from  to . . . . . . . . . . . . . . . . . . . .|   521127|
# | 39.66109-46.47722|from  to . . . . . . . . . . . . . . . . . . . .|    53075|
# |-14.86795--8.05182|from  to . . . . . . . . . . . . . . . . . . . .|    16187|
# | 46.47722-53.29335|from  to . . . . . . . . . . . . . . . . . . . .|      132|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                    #|description                                  |    count|
# |-----------------------------------------------------------------------------|
# | -11.708438--4.712622|from  to . . . . . . . . . . . . . . . . . . | 46356982|
# |                    *|no data. . . . . . . . . . . . . . . . . . . | 38380628|
# |-18.704254--11.708438|from  to . . . . . . . . . . . . . . . . . . | 37234687|
# |   -4.712622-2.283194|from  to . . . . . . . . . . . . . . . . . . | 18714763|
# | -25.70007--18.704254|from  to . . . . . . . . . . . . . . . . . . | 11671795|
# | -32.695886--25.70007|from  to . . . . . . . . . . . . . . . . . . |  3781513|
# |-39.691702--32.695886|from  to . . . . . . . . . . . . . . . . . . |   612036|
# |     2.283194-9.27901|from  to . . . . . . . . . . . . . . . . . . |   336970|
# |-46.687518--39.691702|from  to . . . . . . . . . . . . . . . . . . |    14459|
# |-53.683334--46.687518|from  to . . . . . . . . . . . . . . . . . . |      678|
# |    9.27901-16.274826|from  to . . . . . . . . . . . . . . . . . . |      590|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# ----- BAND 11 -------
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                   #|description                                   |    count|
# |-----------------------------------------------------------------------------|
# | 11.956204-18.756935|from  to . . . . . . . . . . . . . . . . . . .| 35998724|
# |  5.155473-11.956204|from  to . . . . . . . . . . . . . . . . . . .| 35795646|
# |  -1.645258-5.155473|from  to . . . . . . . . . . . . . . . . . . .| 35505351|
# |                   *|no data. . . . . . . . . . . . . . . . . . . .| 30277073|
# | 18.756935-25.557666|from  to . . . . . . . . . . . . . . . . . . .| 13227556|
# | 25.557666-32.358397|from  to . . . . . . . . . . . . . . . . . . .|  4254155|
# | -8.445988--1.645258|from  to . . . . . . . . . . . . . . . . . . .|  1318993|
# | 32.358397-39.159128|from  to . . . . . . . . . . . . . . . . . . .|   644007|
# | 39.159128-45.959859|from  to . . . . . . . . . . . . . . . . . . .|    67813|
# |-15.246719--8.445988|from  to . . . . . . . . . . . . . . . . . . .|    15528|
# |  45.959859-52.76059|from  to . . . . . . . . . . . . . . . . . . .|      255|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+
#
# +-----------------------------------------------------------------------------+
# |                       Category Information                        |     cell|
# |                    #|description                                  |    count|
# |-----------------------------------------------------------------------------|
# |  -10.11842--3.143617|from  to . . . . . . . . . . . . . . . . . . | 44186456|
# |                    *|no data. . . . . . . . . . . . . . . . . . . | 38390178|
# | -17.093224--10.11842|from  to . . . . . . . . . . . . . . . . . . | 35457529|
# |-24.068027--17.093224|from  to . . . . . . . . . . . . . . . . . . | 20849914|
# |   -3.143617-3.831186|from  to . . . . . . . . . . . . . . . . . . | 11707578|
# | -31.04283--24.068027|from  to . . . . . . . . . . . . . . . . . . |  5192839|
# | -38.017633--31.04283|from  to . . . . . . . . . . . . . . . . . . |  1176205|
# |   3.831186-10.805989|from  to . . . . . . . . . . . . . . . . . . |    91347|
# |-44.992436--38.017633|from  to . . . . . . . . . . . . . . . . . . |    51610|
# |-51.967239--44.992436|from  to . . . . . . . . . . . . . . . . . . |     1073|
# |  10.805989-17.780792|from  to . . . . . . . . . . . . . . . . . . |      372|
# |-----------------------------------------------------------------------------|
# |TOTAL                                                              |157105101|
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Итак, видно, что мода почти во всех каналах приходится приблизительно на диапазон от -0.05 до 0.15 (для разности 16-го года и 15-го) и от -0.1 до 0.15 для разности 17-го года и 16-го. В температурных каналах это различие, понятное дело, больше. Вообще, это довольно большая разность, особенно если учесть, что сами данные лежат в диапазоне от нуля до единицы, а основной массив плотности гистограммы приходится на диапазон (0.1, 0.4).
# Правда, есть и хорошая новость: основная часть больших различий приходится на территории, которые не покрыты лесами. Внутри залесенных участков разносит в обычно меньше.

# %% [markdown]
# **TODO:** положить картинки разностей для наглядности.

# %%
# grs.rast.RasterRow('diff1615.1')

# %% [markdown]
# ## Нормализация базовых слоев относительно друг друга

# %% [markdown]
# Посмотрим, насколько эти базовые слои "бъются" между собой при использовании процедуры нормализации, описанной в [соответствующем документе](007_Normalization.ipynb). Для этого найдем псевдоинвариантные пиксели для разных пар растров и посчитаем относительно этих пикселей нормирующие коэффициенты. Степень близости полученных коэффициентов будет служить оценкой схожести базовых слоев на неизменившихся участках.

# %% [markdown]
# Импортируем функции нормализации, описанные в указанном документе.

# %%
import normalization
reload(normalization)

from normalization import get_norm_coef, find_pif

# %% [markdown]
# Возмем для примера 5-й канал и рассчитаем нормирующие коэффициенты для каждой пары растров:

# %%
REGR_EPS = 0.35
MAXITER = 50

grs.grass.run_command('g.region', region='all_scenes@landsat', res=120)

params1615 = find_pif(grs.grass, 'composite16.5', 'composite15.5', 
                      'tmp.PIF.1615', regression_eps=REGR_EPS, max_iteration=MAXITER)
print params1615

params1716 = find_pif(grs.grass, 'composite17.5', 'composite16.5', 
                      'tmp.PIF.1716', regression_eps=REGR_EPS, max_iteration=MAXITER)
print params1716


params1715 = find_pif(grs.grass, 'composite17.5', 'composite15.5', 
                      'tmp.PIF.1715', regression_eps=REGR_EPS, max_iteration=MAXITER)
print params1715

# %% [raw]
# {'b': 1.349415, 'good_quality': True, 'iterations': 24, 'N': 167064}
# {'b': 0.773133, 'good_quality': True, 'iterations': 1, 'N': 1662349}
# {'b': 1.086193, 'good_quality': True, 'iterations': 1, 'N': 2443625}

# %% [markdown]
# Нормирующие коэффициенты для 15-го года:

# %%
print get_norm_coef(grs.grass, 'composite15.5', 'tmp.PIF.1615')
print get_norm_coef(grs.grass, 'composite15.5', 'tmp.PIF.1715')

# %% [markdown]
# {'intercept': -93.68254592043874, 'factor': 472.2852372468748}
# {'intercept': -7.6259174283960025, 'factor': 34.73406255368474}

# %% [markdown]
# Нормирующие коэффициенты для 16-го года:

# %%
print get_norm_coef(grs.grass, 'composite16.5', 'tmp.PIF.1615')
print get_norm_coef(grs.grass, 'composite16.5', 'tmp.PIF.1716')

# %% [raw]
# {'intercept': -174.38351084210203, 'factor': 860.2938747534757}
# {'intercept': -23.255531168355063, 'factor': 100.4535054822106}

# %% [markdown]
# Нормирующие коэффициенты для 17-го года:

# %%
print get_norm_coef(grs.grass, 'composite17.5', 'tmp.PIF.1715')
print get_norm_coef(grs.grass, 'composite17.5', 'tmp.PIF.1716')

# %% [raw]
# {'intercept': -8.281840020664953, 'factor': 41.072495739980674}
# {'intercept': -13.357644018461274, 'factor': 60.35812568631284}
